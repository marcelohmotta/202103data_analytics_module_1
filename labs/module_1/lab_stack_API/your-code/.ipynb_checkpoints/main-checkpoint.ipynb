# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
import pandas as pd
import datetime
from datetime import date

# %%
# import the necessary libraries here
from stackapi import StackAPI

# %%
# run the code below
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

# %% [markdown]
# Before you start with the lab, please be aware that all the relevant information regarding the StackAPI can be found here: https://stackapi.readthedocs.io/en/latest/user/advanced.html#calling-fetch-with-various-api-parameters

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.
#
# *hint*: use the fromdate and todate arguments.

# %%
# your code here

start = datetime.datetime(2021, 3, 1)
end = datetime.datetime(2021, 3, 31)

questions = SITE.fetch('questions', fromdate = start, todate=end)
answers = SITE.fetch('answers', fromdate = start, todate=end)

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here

today = date.today()
today
# Out:
# datetime.date(2021, 4, 25)

# %%
yesterday = datetime.datetime(2021, 4, 16)

# %%
questions = SITE.fetch('questions', fromdate=yesterday, todate=today, min=5, tagged='python', sort='votes')
questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 211,
#  'total': 0,
#  'items': [{'tags': ['python', 'numpy'],
#    'owner': {'reputation': 1042,
#     'user_id': 7462275,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/JtXPb.png?s=128&g=1',
#     'display_name': 'Stef1611',
#     'link': 'https://stackoverflow.com/users/7462275/stef1611'},
#    'is_answered': True,
#    'view_count': 626,
#    'closed_date': 1618933680,
#    'accepted_answer_id': 67181405,
#    'answer_count': 2,
#    'score': 17,
#    'last_activity_date': 1618932902,
#    'creation_date': 1618927799,
#    'last_edit_date': 1618928489,
#    'question_id': 67180635,
#    'link': 'https://stackoverflow.com/questions/67180635/why-is-a-a100-almost-two-times-faster-than-a-100',
#    'closed_reason': 'Duplicate',
#    'title': 'Why is a=a*100 almost two times faster than a*=100?'},
#   {'tags': ['python', 'machine-learning', 'xgboost'],
#    'owner': {'reputation': 83,
#     'user_id': 15658606,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c1d8dde838b0e73b06d23a57624a8b61?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'gwanim',
#     'link': 'https://stackoverflow.com/users/15658606/gwanim'},
#    'is_answered': True,
#    'view_count': 118,
#    'accepted_answer_id': 67123899,
#    'answer_count': 1,
#    'score': 8,
#    'last_activity_date': 1618580211,
#    'creation_date': 1618566114,
#    'last_edit_date': 1618580211,
#    'question_id': 67122859,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67122859/why-does-xgboost-with-datasets-of-zeros-return-a-non-zero-prediction',
#    'title': 'Why does XGBoost with datasets of zeros return a non-zero prediction?'},
#   {'tags': ['python', 'django'],
#    'owner': {'reputation': 429,
#     'user_id': 10443788,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0fae6ec37c80b406fd0d3127bbeac911?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'user',
#     'link': 'https://stackoverflow.com/users/10443788/user'},
#    'is_answered': True,
#    'view_count': 190,
#    'bounty_amount': 200,
#    'bounty_closes_date': 1619758043,
#    'accepted_answer_id': 67236911,
#    'answer_count': 1,
#    'score': 8,
#    'last_activity_date': 1619292272,
#    'creation_date': 1618898481,
#    'question_id': 67173283,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67173283/django-return-each-model-value-without-field',
#    'title': 'Django - return each model value without field'},
#   {'tags': ['python', 'pytorch'],
#    'owner': {'reputation': 696,
#     'user_id': 14735451,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/BlY6t.jpg?s=128&g=1',
#     'display_name': 'Penguin',
#     'link': 'https://stackoverflow.com/users/14735451/penguin'},
#    'is_answered': True,
#    'view_count': 76,
#    'accepted_answer_id': 67206850,
#    'answer_count': 1,
#    'score': 7,
#    'last_activity_date': 1619095874,
#    'creation_date': 1619058948,
#    'last_edit_date': 1619095127,
#    'question_id': 67205948,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67205948/how-to-load-a-pre-trained-pytorch-model',
#    'title': 'How to load a pre-trained PyTorch model?'},
#   {'tags': ['python', 'compilation', 'electron', 'exe'],
#    'owner': {'reputation': 415,
#     'user_id': 12874556,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AAuE7mDSQFdX2I_mZxfvEFgiYZMET66X7zzM5Ynqr7e2=k-s128',
#     'display_name': 'Pro Chess',
#     'link': 'https://stackoverflow.com/users/12874556/pro-chess'},
#    'is_answered': True,
#    'view_count': 197,
#    'bounty_amount': 50,
#    'bounty_closes_date': 1619543784,
#    'accepted_answer_id': 67220101,
#    'answer_count': 1,
#    'score': 7,
#    'last_activity_date': 1619123084,
#    'creation_date': 1618735316,
#    'last_edit_date': 1619102783,
#    'question_id': 67146654,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67146654/how-to-compile-python-electron-js-into-desktop-app-exe',
#    'title': 'How to compile Python + Electron JS into desktop app (exe)'},
#   {'tags': ['python', 'python-3.x', 'pip', 'homebrew', 'apple-m1'],
#    'owner': {'reputation': 163,
#     'user_id': 8149861,
#     'user_type': 'registered',
#     'accept_rate': 60,
#     'profile_image': 'https://i.stack.imgur.com/Cu1Qz.jpg?s=128&g=1',
#     'display_name': 'daquezada',
#     'link': 'https://stackoverflow.com/users/8149861/daquezada'},
#    'is_answered': True,
#    'view_count': 3146,
#    'accepted_answer_id': 67244602,
#    'answer_count': 3,
#    'score': 6,
#    'last_activity_date': 1619332064,
#    'creation_date': 1619277272,
#    'question_id': 67244301,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67244301/warning-messages-when-i-update-pip-or-install-packages',
#    'title': 'WARNING messages when I update PIP or install Packages'},
#   {'tags': ['python', 'python-3.x', 'dictionary', 'data-structures'],
#    'owner': {'reputation': 127,
#     'user_id': 15560122,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/ebb9bc1952cf05b587d130d9adb5bb7d?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'nerdyGuy',
#     'link': 'https://stackoverflow.com/users/15560122/nerdyguy'},
#    'is_answered': True,
#    'view_count': 102,
#    'accepted_answer_id': 67155742,
#    'answer_count': 3,
#    'score': 6,
#    'last_activity_date': 1618931231,
#    'creation_date': 1618803905,
#    'last_edit_date': 1618931231,
#    'question_id': 67155711,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67155711/robot-return-to-origin',
#    'title': 'Robot return to origin'},
#   {'tags': ['python', 'python-import'],
#    'owner': {'reputation': 1007,
#     'user_id': 5758423,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/VLzyY.jpg?s=128&g=1',
#     'display_name': 'thorwhalen',
#     'link': 'https://stackoverflow.com/users/5758423/thorwhalen'},
#    'is_answered': True,
#    'view_count': 73,
#    'accepted_answer_id': 67185855,
#    'answer_count': 1,
#    'score': 6,
#    'last_activity_date': 1619020908,
#    'creation_date': 1618942123,
#    'last_edit_date': 1618942850,
#    'question_id': 67184177,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67184177/dynamically-getting-a-list-of-standard-library-python-packages-names',
#    'title': 'Dynamically getting a list of standard library python packages names'},
#   {'tags': ['python', 'tensorflow', 'keras', 'deep-learning'],
#    'owner': {'reputation': 103,
#     'user_id': 14559548,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/714af0e57ec33f7592e7cfd61056da83?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Lucas Pelizzari',
#     'link': 'https://stackoverflow.com/users/14559548/lucas-pelizzari'},
#    'is_answered': True,
#    'view_count': 86,
#    'accepted_answer_id': 67185664,
#    'answer_count': 1,
#    'score': 6,
#    'last_activity_date': 1618968036,
#    'creation_date': 1618879412,
#    'last_edit_date': 1618968036,
#    'question_id': 67171002,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67171002/how-to-build-a-tensorflow-model-with-more-than-one-input',
#    'title': 'How to build a Tensorflow model with more than one input?'},
#   {'tags': ['python', 'numpy', 'matrix', 'linear-equation'],
#    'owner': {'reputation': 63,
#     'user_id': 15356301,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/2420961903003cd45f3cc5a1f1e89bb6?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'David_D',
#     'link': 'https://stackoverflow.com/users/15356301/david-d'},
#    'is_answered': True,
#    'view_count': 55,
#    'accepted_answer_id': 67152256,
#    'answer_count': 1,
#    'score': 6,
#    'last_activity_date': 1618850469,
#    'creation_date': 1618758298,
#    'last_edit_date': 1618850469,
#    'question_id': 67150047,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67150047/create-and-solve-different-combinations-of-linear-equation-systems-using-data-st',
#    'title': 'Create and solve different combinations of linear equation systems using data stored in several matrices in python'},
#   {'tags': ['python', 'pandas'],
#    'owner': {'reputation': 323,
#     'user_id': 11986167,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/SGzb0.jpg?s=128&g=1',
#     'display_name': 'ProcolHarum',
#     'link': 'https://stackoverflow.com/users/11986167/procolharum'},
#    'is_answered': True,
#    'view_count': 90,
#    'accepted_answer_id': 67150857,
#    'answer_count': 4,
#    'score': 5,
#    'last_activity_date': 1618819681,
#    'creation_date': 1618762630,
#    'question_id': 67150765,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67150765/how-to-get-a-subgroup-start-finish-indexes-of-dataframe',
#    'title': 'how to get a subgroup start finish indexes of dataframe'},
#   {'tags': ['python', 'pandas', 'numpy', 'apply'],
#    'owner': {'reputation': 1452,
#     'user_id': 1631190,
#     'user_type': 'registered',
#     'accept_rate': 88,
#     'profile_image': 'https://www.gravatar.com/avatar/836027d028a25e83e63fbf1bfef7fafe?s=128&d=identicon&r=PG',
#     'display_name': 'J-H',
#     'link': 'https://stackoverflow.com/users/1631190/j-h'},
#    'is_answered': True,
#    'view_count': 131,
#    'accepted_answer_id': 67227105,
#    'answer_count': 3,
#    'score': 5,
#    'last_activity_date': 1619170643,
#    'creation_date': 1619166791,
#    'question_id': 67226612,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67226612/apply-a-function-to-each-cell-of-a-pandas-dataframe-using-information-from-a-par',
#    'title': 'Apply a function to each cell of a pandas dataframe using information from a particular column'},
#   {'tags': ['python', 'pandas', 'performance', 'numpy', 'combinations'],
#    'owner': {'reputation': 65,
#     'user_id': 10567768,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a20fc631d8a8b62955fe9b311f8b6fc4?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'mr7',
#     'link': 'https://stackoverflow.com/users/10567768/mr7'},
#    'is_answered': True,
#    'view_count': 117,
#    'accepted_answer_id': 67162213,
#    'answer_count': 3,
#    'score': 5,
#    'last_activity_date': 1618864096,
#    'creation_date': 1618833362,
#    'last_edit_date': 1618864096,
#    'question_id': 67161539,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67161539/faster-way-to-sum-all-combinations-of-rows-in-dataframe',
#    'title': 'Faster way to sum all combinations of rows in dataframe'},
#   {'tags': ['python', 'web-scraping', 'python-requests'],
#    'owner': {'reputation': 706,
#     'user_id': 12195215,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1eb7fab44b90ad39d969c5cbb3900fce?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'gython',
#     'link': 'https://stackoverflow.com/users/12195215/gython'},
#    'is_answered': True,
#    'view_count': 50,
#    'accepted_answer_id': 67246516,
#    'answer_count': 3,
#    'score': 5,
#    'last_activity_date': 1619301187,
#    'creation_date': 1619290634,
#    'last_edit_date': 1619301187,
#    'question_id': 67246415,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67246415/scraping-data-from-a-dynamic-web-table',
#    'title': 'Scraping data from a dynamic web table'},
#   {'tags': ['python', 'json', 'pandas'],
#    'owner': {'reputation': 1741,
#     'user_id': 1013388,
#     'user_type': 'registered',
#     'accept_rate': 39,
#     'profile_image': 'https://www.gravatar.com/avatar/0b0076ca8bd838d53e2df495a9d5324c?s=128&d=identicon&r=PG',
#     'display_name': 'A.G.',
#     'link': 'https://stackoverflow.com/users/1013388/a-g'},
#    'is_answered': True,
#    'view_count': 41,
#    'accepted_answer_id': 67188069,
#    'answer_count': 2,
#    'score': 5,
#    'last_activity_date': 1618968138,
#    'creation_date': 1618966582,
#    'question_id': 67188012,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67188012/in-pandas-combine-outer-json-with-nested-json-and-create-new-dataframe',
#    'title': 'In pandas combine outer json with nested json and create new dataframe'},
#   {'tags': ['python', 'multiprocessing', 'python-multiprocessing'],
#    'owner': {'reputation': 521,
#     'user_id': 10044560,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0559e3db9422029207ee0d2c342d6266?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Karl',
#     'link': 'https://stackoverflow.com/users/10044560/karl'},
#    'is_answered': True,
#    'view_count': 61,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1618680364,
#    'creation_date': 1618606403,
#    'question_id': 67132064,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67132064/python-multiprocessing-pool-as-decorator',
#    'title': 'Python Multiprocessing Pool as Decorator'},
#   {'tags': ['python', 'python-3.x', 'pandas'],
#    'owner': {'reputation': 55,
#     'user_id': 2464443,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/e3d1f7a18f9e5a8757abeff3266629d8?s=128&d=identicon&r=PG',
#     'display_name': 'Alex G&#252;nsberg',
#     'link': 'https://stackoverflow.com/users/2464443/alex-g%c3%bcnsberg'},
#    'is_answered': True,
#    'view_count': 133,
#    'accepted_answer_id': 67159645,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1619186722,
#    'creation_date': 1618824333,
#    'last_edit_date': 1619170292,
#    'question_id': 67159328,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67159328/cumulative-sales-data-with-threshold-value-forming-a-new-series-column-with-a',
#    'title': 'Cumulative sales data with threshold value forming a new series / column with a boolean value?'},
#   {'tags': ['python', 'python-3.x', 'pandas', 'pandas-groupby'],
#    'owner': {'reputation': 1609,
#     'user_id': 12559770,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/80816af816ac0730164c41548116b0db?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'chippycentra',
#     'link': 'https://stackoverflow.com/users/12559770/chippycentra'},
#    'is_answered': True,
#    'view_count': 54,
#    'accepted_answer_id': 67160915,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1618835978,
#    'creation_date': 1618828667,
#    'last_edit_date': 1618830975,
#    'question_id': 67160408,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67160408/keep-only-largest-interval-in-coordinates-row-in-pandas',
#    'title': 'Keep only largest interval in coordinates row in pandas'},
#   {'tags': ['python', 'unit-testing'],
#    'owner': {'reputation': 127,
#     'user_id': 15560122,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/ebb9bc1952cf05b587d130d9adb5bb7d?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'nerdyGuy',
#     'link': 'https://stackoverflow.com/users/15560122/nerdyguy'},
#    'is_answered': True,
#    'view_count': 108,
#    'accepted_answer_id': 67185271,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1618948507,
#    'creation_date': 1618798337,
#    'last_edit_date': 1618948446,
#    'question_id': 67155178,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67155178/how-do-i-unit-test-random-shuffle-operations-in-python',
#    'title': 'How do I unit test random shuffle operations in Python?'},
#   {'tags': ['python', 'jupyter-notebook', 'zshrc', 'nbconvert'],
#    'owner': {'reputation': 69,
#     'user_id': 12766241,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b55c75961a4848fb87b020a3aaa4d82a?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'zzy09ys',
#     'link': 'https://stackoverflow.com/users/12766241/zzy09ys'},
#    'is_answered': False,
#    'view_count': 56,
#    'answer_count': 2,
#    'score': 5,
#    'last_activity_date': 1619290373,
#    'creation_date': 1619237385,
#    'last_edit_date': 1619290373,
#    'question_id': 67239252,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67239252/jupyter-command-not-found-in-terminal-macos',
#    'title': 'jupyter command not found in terminal MacOS'},
#   {'tags': ['python', 'pandas', 'scikit-learn', 'lda', 'topic-modeling'],
#    'owner': {'reputation': 387,
#     'user_id': 11952178,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-ziA6nnP0wx0/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rdSfF5JUzavSv_sEZa2FvHpZ1IWyA/photo.jpg?sz=128',
#     'display_name': 'Jay Taggert',
#     'link': 'https://stackoverflow.com/users/11952178/jay-taggert'},
#    'is_answered': False,
#    'view_count': 39,
#    'answer_count': 0,
#    'score': 5,
#    'last_activity_date': 1619193348,
#    'creation_date': 1619193348,
#    'question_id': 67233215,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67233215/topic-modeling-using-lda-in-python-not-revealing-output-as-desired',
#    'title': 'Topic modeling using LDA in python not revealing output as desired'},
#   {'tags': ['python', 'pyspark'],
#    'owner': {'reputation': 156,
#     'user_id': 7343922,
#     'user_type': 'registered',
#     'accept_rate': 54,
#     'profile_image': 'https://www.gravatar.com/avatar/08316dc9d3429c385ee137d696188a8c?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'user7343922',
#     'link': 'https://stackoverflow.com/users/7343922/user7343922'},
#    'is_answered': False,
#    'view_count': 77,
#    'bounty_amount': 50,
#    'bounty_closes_date': 1619462549,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1619073845,
#    'creation_date': 1618683484,
#    'last_edit_date': 1618953060,
#    'question_id': 67141530,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67141530/error-while-importing-pyspark-etl-module-and-running-as-child-process-using-pyth',
#    'title': 'Error while Importing pyspark ETL module and running as child process using pything subprocess'},
#   {'tags': ['python', 'pandas'],
#    'owner': {'reputation': 502,
#     'user_id': 5954086,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/fe516d083abbdcf584f22998e2b0e086?s=128&d=identicon&r=PG',
#     'display_name': 'Giovanni Rescia',
#     'link': 'https://stackoverflow.com/users/5954086/giovanni-rescia'},
#    'is_answered': False,
#    'view_count': 47,
#    'answer_count': 0,
#    'score': 5,
#    'last_activity_date': 1618615044,
#    'creation_date': 1618613916,
#    'question_id': 67133093,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/67133093/pandas-changing-values-when-inferring-dtypes',
#    'title': 'Pandas changing values when inferring dtypes'}]}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here

answers_ids = SITE.fetch('answers', ids=[6784, 6473])
answers_ids
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 210,
#  'total': 0,
#  'items': [{'owner': {'reputation': 29483,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'}]}
